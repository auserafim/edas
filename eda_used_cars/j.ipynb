# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('carros_usados.csv', sep=';')
df.tail(5)
# Out:
#       data.set  total.cost  lot.sale.days overage  mileage   vehicle.type  \
# 7490     TRAIN        4625             37      NO    67131  FAMILY.MEDIUM
# 7491      TEST        4024             37      NO    77425         LUXURY
# 7492     TRAIN        4910             33      NO    61011         LUXURY
# 7493      TEST        4669              3      NO    81518         LUXURY
# 7494  VALIDATE        6078             69      NO    76281  FAMILY.MEDIUM
#
#      domestic.import  vehicle.age vehicle.age.group color.set   makex state  \
# 7490        Domestic            5              FIVE       RED   BUICK    TX
# 7491        Domestic            9            SEVEN+      GOLD   OTHER    TX
# 7492          Import            5              FIVE      BLUE  NISSAN    TX
# 7493          Import            6               SIX     WHITE  NISSAN    VA
# 7494        Domestic            6               SIX      BLUE    FORD    NV
#
#             make.model
# 7490     BUICK.SKYLARK
# 7491  LINCOLN.TOWN CAR
# 7492     NISSAN.ALTIMA
# 7493     NISSAN.ALTIMA
# 7494       FORD.TAURUS

# %%
# convertendo primeiro as colunas para seus respectivos tipos de dados
df['vehicle.type'] = df['vehicle.type'].astype('category')
df['vehicle.age.group'] = df['vehicle.age.group'].astype('category')
df['domestic.import'] = df['domestic.import'].astype('category')
df['color.set'] = df['color.set'].astype('category')
df['state'] = df['state'].astype('category')
df['makex'] = df['makex'].astype('category')
df['make.model'] = df['make.model'].astype('category')
df['lot.sale.days'] = df['lot.sale.days'].astype('int')
df['mileage'] = df['mileage'].astype('int')
df['total.cost'] = df['total.cost'].astype('int')
